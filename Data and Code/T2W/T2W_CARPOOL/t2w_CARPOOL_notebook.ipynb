# %% [markdown]
# Open "t2w_CARPOOL.xlsx" with pandas

# %%
import pandas as pd

df = pd.read_excel("t2w_CARPOOL.xlsx")
df.head()
# Out:
#     county_name  district_name     mode                      mode_name  \
# 0       Alameda              4  CARPOOL  Car, Truck, or Van: Carpooled
# 1         Butte              3  CARPOOL  Car, Truck, or Van: Carpooled
# 2  Contra Costa              4  CARPOOL  Car, Truck, or Van: Carpooled
# 3     El Dorado              3  CARPOOL  Car, Truck, or Van: Carpooled
# 4        Fresno              6  CARPOOL  Car, Truck, or Van: Carpooled
#
#    pop_total  pop_mode    percent
# 0    1378947    145808  10.573865
# 1     175797     19585  11.140691
# 2     935733    115798  12.375111
# 3     166652     18788  11.273792
# 4     702651     91675  13.047018

# %% [markdown]
# Sort the data by "district_name"

# %%
df_sorted = df.sort_values(by="district_name")
df_sorted.to_excel("t2w_CARPOOL.xlsx", index=False)
df_sorted.head()
# Out:
#    county_name  district_name     mode                      mode_name  \
# 5     Humboldt              1  CARPOOL  Car, Truck, or Van: Carpooled
# 12   Mendocino              1  CARPOOL  Car, Truck, or Van: Carpooled
# 32    Siskiyou              2  CARPOOL  Car, Truck, or Van: Carpooled
# 31      Shasta              2  CARPOOL  Car, Truck, or Van: Carpooled
# 20  Sacramento              3  CARPOOL  Car, Truck, or Van: Carpooled
#
#     pop_total  pop_mode    percent
# 5      116123     12934  11.138190
# 12      74796     35429  47.367506
# 32      33365      4482  13.433238
# 31     139792     14540  10.401167
# 20    1209828    615979  50.914593

# %% [markdown]
# Drop the column "county_name"

# %%
df_sorted = df_sorted.drop(columns=["county_name"])
df_sorted.to_excel("t2w_CARPOOL.xlsx", index=False)
df_sorted.head()
# Out:
#     district_name     mode                      mode_name  pop_total  \
# 5               1  CARPOOL  Car, Truck, or Van: Carpooled     116123
# 12              1  CARPOOL  Car, Truck, or Van: Carpooled      74796
# 32              2  CARPOOL  Car, Truck, or Van: Carpooled      33365
# 31              2  CARPOOL  Car, Truck, or Van: Carpooled     139792
# 20              3  CARPOOL  Car, Truck, or Van: Carpooled    1209828
#
#     pop_mode    percent
# 5      12934  11.138190
# 12     35429  47.367506
# 32      4482  13.433238
# 31     14540  10.401167
# 20    615979  50.914593

# %% [markdown]
# Clear the "percent" column

# %%
df_sorted["percent"] = None
df_sorted.to_excel("t2w_CARPOOL.xlsx", index=False)
df_sorted.head()
# Out:
#     district_name     mode                      mode_name  pop_total  \
# 5               1  CARPOOL  Car, Truck, or Van: Carpooled     116123
# 12              1  CARPOOL  Car, Truck, or Van: Carpooled      74796
# 32              2  CARPOOL  Car, Truck, or Van: Carpooled      33365
# 31              2  CARPOOL  Car, Truck, or Van: Carpooled     139792
# 20              3  CARPOOL  Car, Truck, or Van: Carpooled    1209828
#
#     pop_mode percent
# 5      12934    None
# 12     35429    None
# 32      4482    None
# 31     14540    None
# 20    615979    None

# %% [markdown]
# Merge the rows for each "district_name"

# %%
df_merged = df_sorted.groupby("district_name", as_index=False).agg({
    **{col: "first" for col in df_sorted.columns if col not in ["pop_total", "pop_mode", "district_name"]},
    "pop_total": "sum",
    "pop_mode": "sum"
})
df_merged.to_excel("t2w_CARPOOL.xlsx", index=False)
df_merged.head()
# Out:
#    district_name     mode                      mode_name percent  pop_total  \
# 0              1  CARPOOL  Car, Truck, or Van: Carpooled    None     190919
# 1              2  CARPOOL  Car, Truck, or Van: Carpooled    None     173157
# 2              3  CARPOOL  Car, Truck, or Van: Carpooled    None    2251682
# 3              4  CARPOOL  Car, Truck, or Van: Carpooled    None    6681497
# 4              5  CARPOOL  Car, Truck, or Van: Carpooled    None    1258819
#
#    pop_mode
# 0     48363
# 1     19022
# 2    885836
# 3    839486
# 4    313475

# %% [markdown]
# Calculate the "percent" by formula: "pop_mode"/"pop_total"*100

# %%
df_merged["percent"] = (df_merged["pop_mode"] / df_merged["pop_total"]) * 100
df_merged.to_excel("t2w_CARPOOL.xlsx", index=False)
df_merged.head()
# Out:
#    district_name     mode                      mode_name    percent  \
# 0              1  CARPOOL  Car, Truck, or Van: Carpooled  25.331685
# 1              2  CARPOOL  Car, Truck, or Van: Carpooled  10.985406
# 2              3  CARPOOL  Car, Truck, or Van: Carpooled  39.341079
# 3              4  CARPOOL  Car, Truck, or Van: Carpooled  12.564340
# 4              5  CARPOOL  Car, Truck, or Van: Carpooled  24.902309
#
#    pop_total  pop_mode
# 0     190919     48363
# 1     173157     19022
# 2    2251682    885836
# 3    6681497    839486
# 4    1258819    313475
