# %% [markdown]
# Open the file "Average_Transit_Speeds_by_Route_Time_of_Day.csv" using Pandas

# %%
import pandas as pd

# Open the CSV file
df = pd.read_csv("Average_Transit_Speeds_by_Route_Time_of_Day.csv")

# Display the first few rows of the dataframe
print(df.head())
# Out:
#    OBJECTID route_id  direction_id time_period  speed_mph  \
# 0         1     2018             1        peak  28.405959
# 1         2     2018             1     all_day  28.405959
# 2         3     2018             0        peak  24.626770
# 3         4     2018             0     all_day  24.626770
# 4         5      154             0     offpeak  16.258245
#
#                                           base64_url             org_id  \
# 0  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 1  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 2  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 3  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 4  aHR0cHM6Ly9ob3N0ZWQtZ3Rmcy1mZWVkcy5zMy5hbWF6b2...  recx4ZG2lvZb7kGAL
#
#                    agency district_name                          route_name  \
# 0  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 1  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 2  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 3  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 4           Shasta County  02 - Redding
#
#    Shape_Length
# 0  40360.145656
# 1  40360.145656
# 2  43101.644534
# 3  43101.644534
# 4  13821.396517

# %% [markdown]
# Create a new file "avgts.csv" as a clone of "Average_Transit_Speeds_by_Route_Time_of_Day.csv"

# %%
# Save the dataframe to a new CSV file
df.to_csv("avgts.csv", index=False)

print("File 'avgts.csv' created successfully.")
# Out:
# File 'avgts.csv' created successfully.

# %% [markdown]
# Open 'avgts.csv' using Pandas

# %%
import pandas as pd
# Open the CSV file
df = pd.read_csv("avgts.csv")

# Display the first few rows of the dataframe
print(df.head())
# Out:
#    OBJECTID route_id  direction_id time_period  speed_mph  \
# 0         1     2018             1        peak  28.405959
# 1         2     2018             1     all_day  28.405959
# 2         3     2018             0        peak  24.626770
# 3         4     2018             0     all_day  24.626770
# 4         5      154             0     offpeak  16.258245
#
#                                           base64_url             org_id  \
# 0  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 1  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 2  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 3  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 4  aHR0cHM6Ly9ob3N0ZWQtZ3Rmcy1mZWVkcy5zMy5hbWF6b2...  recx4ZG2lvZb7kGAL
#
#                    agency district_name                          route_name  \
# 0  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 1  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 2  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 3  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 4           Shasta County  02 - Redding
#
#    Shape_Length
# 0  40360.145656
# 1  40360.145656
# 2  43101.644534
# 3  43101.644534
# 4  13821.396517

# %% [markdown]
# Remove the rows with no data in column "district_name"

# %%
# Remove rows with missing values in 'district_name'
df.dropna(subset=['district_name'], inplace=True)

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Updated 'avgts.csv' successfully by removing rows with no data in 'district_name'.")
print(df.head())
# Out:
# Updated 'avgts.csv' successfully by removing rows with no data in 'district_name'.
#    OBJECTID route_id  direction_id time_period  speed_mph  \
# 0         1     2018             1        peak  28.405959
# 1         2     2018             1     all_day  28.405959
# 2         3     2018             0        peak  24.626770
# 3         4     2018             0     all_day  24.626770
# 4         5      154             0     offpeak  16.258245
#
#                                           base64_url             org_id  \
# 0  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 1  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 2  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 3  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 4  aHR0cHM6Ly9ob3N0ZWQtZ3Rmcy1mZWVkcy5zMy5hbWF6b2...  recx4ZG2lvZb7kGAL
#
#                    agency district_name                          route_name  \
# 0  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 1  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 2  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 3  Lake Transit Authority   01 - Eureka  Soda Bay, Kit?s Corner to Lakeport
# 4           Shasta County  02 - Redding
#
#    Shape_Length
# 0  40360.145656
# 1  40360.145656
# 2  43101.644534
# 3  43101.644534
# 4  13821.396517

# %% [markdown]
# Check if there are any empty rows in "district_name"

# %%
# Check for missing values in 'district_name'
missing_values = df['district_name'].isnull().sum()

if missing_values == 0:
    print("No empty rows found in 'district_name'.")
else:
    print(f"Found {missing_values} empty rows in 'district_name'.")
# Out:
# No empty rows found in 'district_name'.

# %% [markdown]
# Strip so that the remaining values so that there are only number is the column "district_name"

# %%
# Extract numbers from 'district_name'
df['district_name'] = df['district_name'].str.extract(r'(\d+)')

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Updated 'district_name' column to contain only numbers and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Updated 'district_name' column to contain only numbers and saved to 'avgts.csv'.
#    OBJECTID route_id  direction_id time_period  speed_mph  \
# 0         1     2018             1        peak  28.405959
# 1         2     2018             1     all_day  28.405959
# 2         3     2018             0        peak  24.626770
# 3         4     2018             0     all_day  24.626770
# 4         5      154             0     offpeak  16.258245
#
#                                           base64_url             org_id  \
# 0  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 1  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 2  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 3  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 4  aHR0cHM6Ly9ob3N0ZWQtZ3Rmcy1mZWVkcy5zMy5hbWF6b2...  recx4ZG2lvZb7kGAL
#
#                    agency district_name                          route_name  \
# 0  Lake Transit Authority            01  Soda Bay, Kit?s Corner to Lakeport
# 1  Lake Transit Authority            01  Soda Bay, Kit?s Corner to Lakeport
# 2  Lake Transit Authority            01  Soda Bay, Kit?s Corner to Lakeport
# 3  Lake Transit Authority            01  Soda Bay, Kit?s Corner to Lakeport
# 4           Shasta County            02
#
#    Shape_Length
# 0  40360.145656
# 1  40360.145656
# 2  43101.644534
# 3  43101.644534
# 4  13821.396517

# %% [markdown]
# Remove the "route_name" columnn

# %%
# Remove the 'route_name' column
df.drop(columns=['route_name'], inplace=True)

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Removed 'route_name' column and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Removed 'route_name' column and saved to 'avgts.csv'.
#    OBJECTID route_id  direction_id time_period  speed_mph  \
# 0         1     2018             1        peak  28.405959
# 1         2     2018             1     all_day  28.405959
# 2         3     2018             0        peak  24.626770
# 3         4     2018             0     all_day  24.626770
# 4         5      154             0     offpeak  16.258245
#
#                                           base64_url             org_id  \
# 0  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 1  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 2  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 3  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 4  aHR0cHM6Ly9ob3N0ZWQtZ3Rmcy1mZWVkcy5zMy5hbWF6b2...  recx4ZG2lvZb7kGAL
#
#                    agency district_name  Shape_Length
# 0  Lake Transit Authority            01  40360.145656
# 1  Lake Transit Authority            01  40360.145656
# 2  Lake Transit Authority            01  43101.644534
# 3  Lake Transit Authority            01  43101.644534
# 4           Shasta County            02  13821.396517

# %% [markdown]
# Remove the "agency" columnn

# %%
# Remove the 'agency' column
df.drop(columns=['agency'], inplace=True)

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Removed 'agency' column and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Removed 'agency' column and saved to 'avgts.csv'.
#    OBJECTID route_id  direction_id time_period  speed_mph  \
# 0         1     2018             1        peak  28.405959
# 1         2     2018             1     all_day  28.405959
# 2         3     2018             0        peak  24.626770
# 3         4     2018             0     all_day  24.626770
# 4         5      154             0     offpeak  16.258245
#
#                                           base64_url             org_id  \
# 0  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 1  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 2  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 3  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 4  aHR0cHM6Ly9ob3N0ZWQtZ3Rmcy1mZWVkcy5zMy5hbWF6b2...  recx4ZG2lvZb7kGAL
#
#   district_name  Shape_Length
# 0            01  40360.145656
# 1            01  40360.145656
# 2            01  43101.644534
# 3            01  43101.644534
# 4            02  13821.396517

# %% [markdown]
# Remove the "OBJECTID" columnn

# %%
# Remove the 'OBJECTID' column
df.drop(columns=['OBJECTID'], inplace=True)

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Removed 'OBJECTID' column and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Removed 'OBJECTID' column and saved to 'avgts.csv'.
#   route_id  direction_id time_period  speed_mph  \
# 0     2018             1        peak  28.405959
# 1     2018             1     all_day  28.405959
# 2     2018             0        peak  24.626770
# 3     2018             0     all_day  24.626770
# 4      154             0     offpeak  16.258245
#
#                                           base64_url             org_id  \
# 0  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 1  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 2  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 3  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...  recPwXKbGLL4aIqXV
# 4  aHR0cHM6Ly9ob3N0ZWQtZ3Rmcy1mZWVkcy5zMy5hbWF6b2...  recx4ZG2lvZb7kGAL
#
#   district_name  Shape_Length
# 0            01  40360.145656
# 1            01  40360.145656
# 2            01  43101.644534
# 3            01  43101.644534
# 4            02  13821.396517

# %% [markdown]
# Remove the "base64_url" and "org_id" column

# %%
# Remove the 'base64_url' and 'org_id' columns
df.drop(columns=['base64_url', 'org_id'], inplace=True)

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Removed 'base64_url' and 'org_id' columns and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Removed 'base64_url' and 'org_id' columns and saved to 'avgts.csv'.
#   route_id  direction_id time_period  speed_mph district_name  Shape_Length
# 0     2018             1        peak  28.405959            01  40360.145656
# 1     2018             1     all_day  28.405959            01  40360.145656
# 2     2018             0        peak  24.626770            01  43101.644534
# 3     2018             0     all_day  24.626770            01  43101.644534
# 4      154             0     offpeak  16.258245            02  13821.396517

# %% [markdown]
# Drop the "Shape_Length" column

# %%
# Drop the 'Shape_Length' column
df.drop(columns=['Shape_Length'], inplace=True)

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Dropped 'Shape_Length' column and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Dropped 'Shape_Length' column and saved to 'avgts.csv'.
#   route_id  direction_id time_period  speed_mph district_name
# 0     2018             1        peak  28.405959            01
# 1     2018             1     all_day  28.405959            01
# 2     2018             0        peak  24.626770            01
# 3     2018             0     all_day  24.626770            01
# 4      154             0     offpeak  16.258245            02

# %% [markdown]
# Sort the data by "route_id" than by "district_name"

# %%
# Sort the dataframe by 'route_id' and then by 'district_name'
df.sort_values(by=['route_id', 'district_name'], inplace=True)

# Save the sorted dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Sorted the data by 'route_id' and then by 'district_name'.")
print(df.head())
# Out:
# Sorted the data by 'route_id' and then by 'district_name'.
#      route_id  direction_id time_period  speed_mph district_name
# 5630      001             0     offpeak  16.329605            03
# 5631      001             0        peak  15.863286            03
# 5632      001             0     all_day  16.096055            03
# 5633      001             1     offpeak  11.843262            03
# 5634      001             1        peak  11.247764            03

# %% [markdown]
# Convert all numbers stored as text in "route_id" to numbers

# %%
# Convert numeric strings in 'route_id' to numbers, keep non-numeric as is
def convert_route_id(val):
    try:
        # Remove leading zeros and convert to int if possible
        return int(val) if val.isdigit() else val
    except:
        return val

df['route_id'] = df['route_id'].apply(convert_route_id)

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Converted numeric 'route_id' values from text to numbers and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Converted numeric 'route_id' values from text to numbers and saved to 'avgts.csv'.
#      route_id  direction_id time_period  speed_mph district_name
# 5630        1             0     offpeak  16.329605            03
# 5631        1             0        peak  15.863286            03
# 5632        1             0     all_day  16.096055            03
# 5633        1             1     offpeak  11.843262            03
# 5634        1             1        peak  11.247764            03

# %% [markdown]
# Remove rows that have "all_day" as data "time_period"

# %%
# Remove rows where 'time_period' is 'all_day'
df = df[df['time_period'] != 'all_day']

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Removed rows with 'all_day' in 'time_period' and saved to 'avgts.csv'.")
print(df.head())
# Out:
# Removed rows with 'all_day' in 'time_period' and saved to 'avgts.csv'.
#      route_id  direction_id time_period  speed_mph district_name
# 5630        1             0     offpeak  16.329605            03
# 5631        1             0        peak  15.863286            03
# 5633        1             1     offpeak  11.843262            03
# 5634        1             1        peak  11.247764            03
# 2037  001-132             0     offpeak  10.915345            05

# %% [markdown]
# Remove sets where the data does not contain both "peak" and "offpeak"

# %%
# Keep only groups where both 'peak' and 'offpeak' are present in 'time_period'
grouped = df.groupby(['route_id', 'direction_id'])
valid_groups = grouped.filter(lambda x: set(['peak', 'offpeak']).issubset(set(x['time_period'])))

# Save the filtered dataframe to the CSV file
valid_groups.to_csv("avgts.csv", index=False)

print("Filtered groups to keep only those with both 'peak' and 'offpeak' in 'time_period'.")
print(valid_groups.head())
# Out:
# Filtered groups to keep only those with both 'peak' and 'offpeak' in 'time_period'.
#      route_id  direction_id time_period  speed_mph district_name
# 5630        1             0     offpeak  16.329605            03
# 5631        1             0        peak  15.863286            03
# 5633        1             1     offpeak  11.843262            03
# 5634        1             1        peak  11.247764            03
# 2037  001-132             0     offpeak  10.915345            05

# %% [markdown]
# Sort the data based on "district_name" than "route_id" than "direction_id" than "time_period"

# %%
# Sort the dataframe by 'district_name', then 'route_id', then 'direction_id'
df.sort_values(by=['district_name', 'route_id', 'direction_id'], inplace=True)

# Save the sorted dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Sorted the data by 'district_name', then 'route_id', then 'direction_id'.")
print(df.head())
# Out:
# Sorted the data by 'district_name', then 'route_id', then 'direction_id'.
#      route_id  direction_id time_period  speed_mph district_name
# 2765        3             0     offpeak  12.808311            01
# 2766        3             0        peak  12.598226            01
# 2745        4             0     offpeak  12.142584            01
# 2776        5             0     offpeak  11.193332            01
# 2777        5             0        peak  11.196184            01

# %% [markdown]
# Remove data if its "district_name" and "route_id" and "direction_id" combination does not occur in multiplies of two in the dataset

# %%
# Count occurrences of each group
group_counts = df.groupby(['district_name', 'route_id', 'direction_id']).size().reset_index(name='count')

# Filter groups where count is a multiple of 2
valid_groups = group_counts[group_counts['count'] % 2 == 0][['district_name', 'route_id', 'direction_id']]

# Merge to keep only valid rows
df = df.merge(valid_groups, on=['district_name', 'route_id', 'direction_id'], how='inner')

# Save the updated dataframe to the CSV file
df.to_csv("avgts.csv", index=False)

print("Removed data where ('district_name', 'route_id', 'direction_id') does not occur in multiples of two.")
print(df.head())
# Out:
# Removed data where ('district_name', 'route_id', 'direction_id') does not occur in multiples of two.
#   route_id  direction_id time_period  speed_mph district_name
# 0        3             0     offpeak  12.808311            01
# 1        3             0        peak  12.598226            01
# 2        5             0     offpeak  11.193332            01
# 3        5             0        peak  11.196184            01
# 4        6             0     offpeak  11.810665            01
