# %% [markdown]
# Open the file bottlenecks.csv

# %%
import pandas as pd

# Open the CSV file
df = pd.read_csv('bottlenecks.csv')

# %% [markdown]
# Create a clone of bottlenecks.csv and call it btn.xlsx

# %%
df.to_csv('btn.csv', index=False)

# %% [markdown]
# Open btn.csv

# %%
import pandas as pd

# Open the CSV file
df = pd.read_csv('btn.csv')

# %% [markdown]
# Replace county abbr. with real names

# %%
county_mapping = {
    'ALA': 'Alameda',
    'ALP': 'Alpine',
    'AMA': 'Amador',
    'BUT': 'Butte',
    'CAL': 'Calaveras',
    'COL': 'Colusa',
    'CC': 'Contra Costa',
    'DN': 'Del Norte',
    'ED': 'El Dorado',
    'FRE': 'Fresno',
    'GLE': 'Glenn',
    'HUM': 'Humboldt',
    'IMP': 'Imperial',
    'INY': 'Inyo',
    'KER': 'Kern',
    'KIN': 'Kings',
    'LAK': 'Lake',
    'LAS': 'Lassen',
    'LA': 'Los Angeles',
    'MAD': 'Madera',
    'MRN': 'Marin',
    'MPA': 'Mariposa',
    'MEN': 'Mendocino',
    'MER': 'Merced',
    'MOD': 'Modoc',
    'MNO': 'Mono',
    'MON': 'Monterey',
    'NAP': 'Napa',
    'NEV': 'Nevada',
    'ORA': 'Orange',
    'PLA': 'Placer',
    'PLU': 'Plumas',
    'RIV': 'Riverside',
    'SAC': 'Sacramento',
    'SBT': 'San Benito',
    'SBD': 'San Bernardino',
    'SD': 'San Diego',
    'SF': 'San Francisco',
    'SJ': 'San Joaquin',
    'SLO': 'San Luis Obispo',
    'SM': 'San Mateo',
    'SB': 'Santa Barbara',
    'SCL': 'Santa Clara',
    'SCR': 'Santa Cruz',
    'SHA': 'Shasta',
    'SIE': 'Sierra',
    'SIS': 'Siskiyou',
    'SOL': 'Solano',
    'SON': 'Sonoma',
    'STA': 'Stanislaus',
    'SUT': 'Sutter',
    'TEH': 'Tehama',
    'TRI': 'Trinity',
    'TUL': 'Tulare',
    'TUO': 'Tuolumne',
    'VEN': 'Ventura',
    'YOL': 'Yolo',
    'YUB': 'Yuba'
}

df['County'] = df['County'].replace(county_mapping)
df.to_csv('btn.csv', index=False)

# %% [markdown]
# Remove the "OBJECTID" column

# %%
# Remove the "OBJECTID" column
df = df.drop(columns=['OBJECTID'])

# Save the updated DataFrame to btn.csv
df.to_csv('btn.csv', index=False)
